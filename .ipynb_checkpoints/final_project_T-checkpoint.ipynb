# %%
import pandas as pd

# %%
df = pd.read_csv('Data\data.csv')
df
# Out:
#       Point  Trees  Shrubs  Peren_FG  bare_groun  Annual_FG       ppt  vpdmin  \
# 0         1     11       3        53          12         21   883.683   6.685
# 1         2      4       4        65           9         23   877.244   8.787
# 2         3     11       6        48           9         18   873.914   8.070
# 3         4      4       5        60          11         34   704.602  13.424
# 4         5      4       4        53          14         17   734.499  11.650
# ...     ...    ...     ...       ...         ...        ...       ...     ...
# 3741   3742     28       8        65           2         17   932.945  10.627
# 3742   3743      6       3        69           4         11   777.025  11.552
# 3743   3744      8      17        47          26         25   934.902  12.196
# 3744   3745     26      11        52          42          9   786.995  12.001
# 3745   3746     36      13        29          23          6  1007.570   8.722
#
#        vpdmax    tmin  ...    aspect  Runoff  Frosting_R  Flooding_F  \
# 0     134.035  42.648  ...  215.8400       1           2           3
# 1     147.974  45.900  ...  179.7800       1           2           3
# 2     141.927  45.192  ...  160.1920       1           2           3
# 3     169.462  63.489  ...  352.7510       1           2           1
# 4     167.733  57.603  ...  131.9440       3           2           1
# ...       ...     ...  ...       ...     ...         ...         ...
# 3741  153.454  72.314  ...   12.2011      -1          -1          -1
# 3742  164.495  72.548  ...    1.8026      -1          -1          -1
# 3743  155.452  59.132  ...   -1.0000      -1          -1          -1
# 3744  147.903  49.740  ...   -1.0000      -1          -1          -1
# 3745  157.623  65.217  ...   -1.0000      -1          -1          -1
#
#       BD_depth  AWS_50cm  AWS_25cm  AWS_150cm  AWS_100cm  Min_WTD
# 0          0.0     11.26      5.75      32.26      21.76    153.0
# 1          0.0     11.26      5.75      32.26      21.76    153.0
# 2          0.0     11.26      5.75      32.26      21.76    153.0
# 3          0.0     11.00      5.50      31.52      21.52    153.0
# 4          0.0      8.50      4.25      25.71      17.21    153.0
# ...        ...       ...       ...        ...        ...      ...
# 3741       0.0      0.00      0.00       0.00       0.00      0.0
# 3742       0.0      0.00      0.00       0.00       0.00      0.0
# 3743       0.0      0.00      0.00       0.00       0.00      0.0
# 3744       0.0      0.00      0.00       0.00       0.00      0.0
# 3745       0.0      0.00      0.00       0.00       0.00      0.0
#
# [3746 rows x 25 columns]

# %%
print(df[df["vpdmax"]== -1].index.values)
# Out:
# []

# %%
minus1= df[(df.values.ravel() == -1).reshape(df.shape).any(1)]

# %%
minus1["Point"]-1
# Out:
# 8          8
# 9          9
# 10        10
# 11        11
# 12        12
#         ...
# 3741    3741
# 3742    3742
# 3743    3743
# 3744    3744
# 3745    3745
# Name: Point, Length: 491, dtype: int64

# %%
df.drop(index= minus1["Point"]-1)
# Out:
#       Point  Trees  Shrubs  Peren_FG  bare_groun  Annual_FG      ppt  vpdmin  \
# 0         1     11       3        53          12         21  883.683   6.685
# 1         2      4       4        65           9         23  877.244   8.787
# 2         3     11       6        48           9         18  873.914   8.070
# 3         4      4       5        60          11         34  704.602  13.424
# 4         5      4       4        53          14         17  734.499  11.650
# ...     ...    ...     ...       ...         ...        ...      ...     ...
# 3681   3682     52      11        29           3         18  722.040  10.713
# 3682   3683     56      11        43           4         17  709.550  11.412
# 3683   3684     45      16        45           3         14  722.040  10.713
# 3685   3686     46       4        42           2          8  724.338  13.762
# 3686   3687      1       3        63          16          7  833.588  12.125
#
#        vpdmax    tmin  ...    aspect  Runoff  Frosting_R  Flooding_F  \
# 0     134.035  42.648  ...  215.8400       1           2           3
# 1     147.974  45.900  ...  179.7800       1           2           3
# 2     141.927  45.192  ...  160.1920       1           2           3
# 3     169.462  63.489  ...  352.7510       1           2           1
# 4     167.733  57.603  ...  131.9440       3           2           1
# ...       ...     ...  ...       ...     ...         ...         ...
# 3681  172.212  71.551  ...  334.9970       5           1           1
# 3682  176.852  72.720  ...  320.0010       5           1           1
# 3683  172.212  71.551  ...  279.1220       5           1           1
# 3685  169.969  64.233  ...   26.7332       1           2           5
# 3686  148.190  53.412  ...   80.1383       1           1           5
#
#       BD_depth  AWS_50cm  AWS_25cm  AWS_150cm  AWS_100cm  Min_WTD
# 0          0.0     11.26      5.75      32.26      21.76    153.0
# 1          0.0     11.26      5.75      32.26      21.76    153.0
# 2          0.0     11.26      5.75      32.26      21.76    153.0
# 3          0.0     11.00      5.50      31.52      21.52    153.0
# 4          0.0      8.50      4.25      25.71      17.21    153.0
# ...        ...       ...       ...        ...        ...      ...
# 3681       0.0      5.77      4.08       5.77       5.77      0.0
# 3682       0.0      5.77      4.08       5.77       5.77      0.0
# 3683       0.0      5.77      4.08       5.77       5.77      0.0
# 3685       0.0      3.14      2.39       6.14       4.64      0.0
# 3686       0.0      2.25      1.50       5.25       3.75      0.0
#
# [3255 rows x 25 columns]

# %% [markdown]
# Summarize, Mean, Standard Deviation, and Quartiles

# %%
df.describe()
# Out:
#              Point        Trees       Shrubs     Peren_FG   bare_groun  \
# count  3746.000000  3746.000000  3746.000000  3746.000000  3746.000000
# mean   1873.500000    11.240523     5.217298    58.623599     9.328083
# std    1081.521382    10.956112     2.889654    10.198998     6.124341
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%     937.250000     3.000000     3.000000    52.000000     5.000000
# 50%    1873.500000     8.000000     5.000000    58.000000     9.000000
# 75%    2809.750000    16.750000     7.000000    67.000000    13.000000
# max    3746.000000    63.000000    20.000000    87.000000    58.000000
#
#          Annual_FG          ppt       vpdmin       vpdmax         tmin  ...  \
# count  3746.000000  3746.000000  3746.000000  3746.000000  3746.000000  ...
# mean     18.154298   850.927872    10.935534   158.141797    59.806677  ...
# std       6.027104   124.333186     1.749736    10.945370    11.038637  ...
# min       0.000000   574.183000     6.207000   129.732000    31.118000  ...
# 25%      13.000000   757.337250     9.635000   149.742000    48.651250  ...
# 50%      19.000000   828.502000    11.089500   157.665500    61.027500  ...
# 75%      23.000000   927.054000    12.086000   165.542500    69.426250  ...
# max      41.000000  1212.890000    20.143000   186.481000    86.232000  ...
#
#             aspect       Runoff   Frosting_R   Flooding_F     BD_depth  \
# count  3746.000000  3746.000000  3746.000000  3746.000000  3746.000000
# mean    165.409395     2.790710     2.134277     1.499466     1.171650
# std     105.226881     1.934296     0.811378     1.185639     9.679795
# min      -1.000000    -1.000000    -1.000000    -1.000000     0.000000
# 25%      72.807350     1.000000     2.000000     1.000000     0.000000
# 50%     160.497500     3.000000     2.000000     1.000000     0.000000
# 75%     251.032250     4.000000     3.000000     1.000000     0.000000
# max     359.965000     6.000000     3.000000     5.000000   137.000000
#
#           AWS_50cm     AWS_25cm    AWS_150cm    AWS_100cm      Min_WTD
# count  3746.000000  3746.000000  3746.000000  3746.000000  3746.000000
# mean      9.040497     4.776439    25.774469    17.295059    15.185264
# std       2.058371     1.081744     6.616652     4.202778    31.981142
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       8.300000     4.380000    24.880000    16.300000     0.000000
# 50%       9.690000     5.200000    28.220000    18.810000     0.000000
# 75%      10.310000     5.400000    29.730000    20.040000     0.000000
# max      12.050000     6.080000    34.760000    23.570000   153.000000
#
# [8 rows x 25 columns]

# %%
# Method 1: Look at the correlation
df.corr()['Trees'].abs().sort_values(ascending=False)
# Out:
# Trees         1.000000
# Peren_FG      0.696277
# Shrubs        0.542669
# bare_groun    0.284631
# slope         0.150580
# Flooding_F    0.149832
# dem           0.117642
# Annual_FG     0.110196
# ppt           0.108964
# vpdmax        0.099539
# tmax          0.067245
# AWS_150cm     0.046575
# Point         0.043291
# AWS_25cm      0.042492
# tdmean        0.035446
# Min_WTD       0.034537
# AWS_100cm     0.034174
# AWS_50cm      0.029894
# tmean         0.023423
# Frosting_R    0.022858
# Runoff        0.021703
# aspect        0.020500
# tmin          0.018713
# BD_depth      0.008138
# vpdmin        0.001517
# Name: Trees, dtype: float64

# %% [markdown]
# Drop features where correlation is low, or arbitrary, BD_depth, vpdmin, Point

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')


# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from scipy import stats

# %% [markdown]
# ['Shrubs', 'Peren_FG', 'bare_groun', 'Annual_FG', 'vpdmax', 'tmean',
#        'slope', 'Runoff', 'Flooding_F', 'BD_depth']

# %%
df = df.drop(columns = ['dem', 'Point', 'vpdmin', 'tmin', 'aspect', 'Frosting_R', 'AWS_50cm', 'AWS_100cm', 'Min_WTD', 'tdmean', 'AWS_25cm', 'AWS_150cm', 'tmax', 'ppt']) #data matrix

# %%
df.describe()
# Out:
#             Shrubs     Peren_FG   bare_groun    Annual_FG       vpdmax  \
# count  3746.000000  3746.000000  3746.000000  3746.000000  3746.000000
# mean      5.217298    58.623599     9.328083    18.154298   158.141797
# std       2.889654    10.198998     6.124341     6.027104    10.945370
# min       0.000000     0.000000     0.000000     0.000000   129.732000
# 25%       3.000000    52.000000     5.000000    13.000000   149.742000
# 50%       5.000000    58.000000     9.000000    19.000000   157.665500
# 75%       7.000000    67.000000    13.000000    23.000000   165.542500
# max      20.000000    87.000000    58.000000    41.000000   186.481000
#
#              tmean        slope       Runoff   Flooding_F     BD_depth
# count  3746.000000  3746.000000  3746.000000  3746.000000  3746.000000
# mean    136.053392     2.016946     2.790710     1.499466     1.171650
# std      10.037661     1.993248     1.934296     1.185639     9.679795
# min     116.833000     0.000000    -1.000000    -1.000000     0.000000
# 25%     125.617000     0.481825     1.000000     1.000000     0.000000
# 50%     137.055000     1.444850     3.000000     1.000000     0.000000
# 75%     145.585000     2.956075     4.000000     1.000000     0.000000
# max     155.996000    20.457100     6.000000     5.000000   137.000000

# %% [markdown]
# Pair Plots

# %%
from pandas.plotting import scatter_matrix


sct = scatter_matrix(df, figsize=(50, 30))
plt.savefig(r"sct.png")

# %%
X = df.drop(columns = 'Trees') #data matrix
y = df['Trees']  #quality

X = np.array(X)  # to np array 
y = np.array(y)   # to np array

best_features = ['Shrubs', 'Peren_FG', 'bare_groun', 'Annual_FG', 'vpdmax', 'tmean','slope', 'Runoff', 'Flooding_F', 'BD_depth']
best_df = df[best_features]
X = np.array(best_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-f4b3446a2bb9> in <module>
# ----> 1 X = df.drop(columns = 'Trees') #data matrix
#       2 y = df['Trees']  #quality
#       3
#       4 X = np.array(X)  # to np array
#       5 y = np.array(y)   # to np array
#
# c:\python38\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# c:\python38\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# c:\python38\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# c:\python38\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Trees'] not found in axis"

# %%
# Calculate correlation coefficient
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 24)
    
cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                             hue = 0.5, as_cmap=True)

sns.set_context(font_scale=2)

# Pair grid set up
g = sns.PairGrid(df)

# Scatter plot on the upper triangle
g.map_upper(plt.scatter, s=10, color = 'red')

# Distribution on the diagonal
g.map_diag(sns.distplot, kde=False, color = 'red')

# Density Plot and Correlation coefficients on the lower triangle
g.map_lower(sns.kdeplot, cmap = cmap)
g.map_lower(corrfunc);

# %%
plt.savefig(r"plotpair.png")
